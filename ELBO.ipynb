# %%
import torch

# %% [markdown]
# ![Skärmavbild 2024-12-02 kl. 10.58.05.png](data:image/png;base64,...)

# %% [markdown]
# ![Skärmavbild 2024-12-02 kl. 11.00.46.png](data:image/png;base64,...)

# %% [markdown]
# ![Skärmavbild 2024-12-02 kl. 11.04.06.png](data:image/png;base64,...)

# %% [markdown]
# ![Skärmavbild 2024-12-02 kl. 11.35.14.png](data:image/png;base64,...)

# %% [markdown]
# ![Skärmavbild 2024-12-02 kl. 12.07.26.png](data:image/png;base64,...)

# %%
def compute_elbo(u_d,cov_d ,K):
 elbo= 0
 elbo = compute_equation11(u_d,cov_d ,K)
 return elbo

def compute_equation11(mu_d,cov_d ,K):
  return  0.5 * (torch.trace(cov_d) + mu_d.T * mu_d - torch.log(torch.linalg.det(cov_d)) - K)

def compute_topic_dis(mu_d,cov_d):
   epsilon_d = torch.randn(1)
   delta_d =  mu_d + torch.sqrt(cov_d) * epsilon_d
   return torch.softmax(delta_d)



def compute_equation_6(p_T, alpha):

    K = 10 # chnage
    pass
